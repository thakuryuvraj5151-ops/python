# %% [markdown]
# <a href="https://colab.research.google.com/github/thakuryuvraj5151-ops/python/blob/main/day.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("yuvraj")
# Out:
# yuvraj
